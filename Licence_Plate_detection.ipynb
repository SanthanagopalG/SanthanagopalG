# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthanagopalG/SanthanagopalG/blob/main/Licence_Plate_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-gpu==2.11.0

# %%
# !pip uninstall tensorflow
# !pip install tensorflow
# Out:
# Found existing installation: tensorflow 2.16.1
# Uninstalling tensorflow-2.16.1:
#   Would remove:
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.10/dist-packages/tensorflow-2.16.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tensorflow/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/v1/layers/experimental/__init__.py
#     /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/v1/lite/experimental/microfrontend/__init__.py
#     /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/v1/lite/experimental/microfrontend/python/__init__.py
# ...

# %%
# !git clone https://github.com/aboerzel/German_License_Plate_Recognition.git
# Out:
# Cloning into 'German_License_Plate_Recognition'...
# remote: Enumerating objects: 5129, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 5129 (delta 52), reused 119 (delta 41), pack-reused 4989
# Receiving objects: 100% (5129/5129), 504.93 MiB | 21.62 MiB/s, done.
# Resolving deltas: 100% (2082/2082), done.
# Updating files: 100% (3083/3083), done.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
cd /content/German_License_Plate_Recognition/models/research
# Out:
# /content/German_License_Plate_Recognition/models/research

# %%
pwd
# Out:
# '/content/German_License_Plate_Recognition/models/research'

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 21.55 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
cd cocoapi/PythonAPI
# Out:
# /content/German_License_Plate_Recognition/models/research/cocoapi/PythonAPI

# %%
# !make
# Out:
# python setup.py build_ext --inplace
# running build_ext
# Compiling pycocotools/_mask.pyx because it changed.
# [1/1] Cythonizing pycocotools/_mask.pyx
# /usr/local/lib/python3.10/dist-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /content/German_License_Plate_Recognition/models/research/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-cpython-310
# creating build/temp.linux-x86_64-cpython-310/pycocotools
# ...

# %%
cp -r pycocotools /content/German_License_Plate_Recognition/models/research

# %% [markdown]
# ### Install the Object Detection API

# %%
cd ..
# Out:
# /content/German_License_Plate_Recognition/models/research/cocoapi

# %%
cd ..
# Out:
# /content/German_License_Plate_Recognition/models/research

# %%
cp object_detection/packages/tf2/setup.py  .

# %%
# !python -m pip install .
# Out:
# Processing /content/German_License_Plate_Recognition/models/research
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 49.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 74.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 11.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 19.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.3 MB/s eta 0:00:00
# ...

# %%
cd /content/training_demo/pre-trained-models
# Out:
# /content/training_demo/pre-trained-models

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# --2024-04-13 07:42:01--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.126.207, 74.125.132.207, 74.125.201.207, ...
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.126.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  --.-KB/s    in 0.09s
#
# 2024-04-13 07:42:01 (229 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]

# %%
# !tar -xvf ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Out:
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %%
pwd
# Out:
# '/content/training_demo/pre-trained-models'

# %%
cd /content/training_demo
# Out:
# /content/training_demo

# %%
# Create train data:
# !python generate_tfrecord.py -x /content/training_demo/images/train -l /content/training_demo/annotations/label_map.pbtxt -o /content/training_demo/annotations/train.record

# Create test data:
# !python generate_tfrecord.py -x /content/training_demo/images/test -l /content/training_demo/annotations/label_map.pbtxt -o /content/training_demo/annotations/test.record
# Out:
# Successfully created the TFRecord file: /content/training_demo/annotations/train.record
# Successfully created the TFRecord file: /content/training_demo/annotations/test.record

# %%
pwd
# Out:
# '/content/training_demo'

# %%
# Out:
# /content/training_demo
